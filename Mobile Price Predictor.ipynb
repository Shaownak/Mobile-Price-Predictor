# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# %%
# Reading Data Set
training_data = pd.read_csv('train (1).csv')
training_data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
# Selecting Target
y = training_data.price_range

# %%
# features
features = ['battery_power', 'clock_speed', 'dual_sim', 'four_g', 'int_memory', 'n_cores', 'px_height', 'px_width', 'ram',
           'three_g', 'touch_screen']
X = training_data[features]

# %%
# Select model
model = RandomForestRegressor(random_state=1)
model.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False)

# %%
predicted_price = model.predict(X)

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
predicted_price
# Out:
# array([1.13, 2.01, 1.97, ..., 3.  , 0.05, 2.82])

# %%
# Read test data
test_data = pd.read_csv('test.csv')
val_X = test_data[features]

# %%
# Predict test data
predicted_test_data = model.predict(val_X)
predicted_test_data
# Out:
# array([2.97, 2.97, 2.49, 3.  , 1.07, 3.  , 3.  , 0.99, 2.91, 0.  , 3.  ,
#        2.99, 0.05, 0.03, 2.19, 0.24, 1.95, 0.85, 2.99, 1.99, 0.61, 2.55,
#        1.29, 1.12, 3.  , 0.  , 2.06, 0.  , 2.6 , 0.1 , 2.35, 0.01, 2.99,
#        0.  , 0.2 , 0.95, 2.98, 1.06, 2.18, 1.  , 0.98, 1.9 , 0.  , 0.  ,
#        0.  , 0.88, 0.11, 2.86, 1.  , 2.01, 1.09, 0.02, 2.74, 0.01, 3.  ,
#        0.94, 2.99, 1.05, 0.65, 3.  , 3.  , 2.57, 0.01, 1.33, 0.92, 0.99,
#        1.21, 2.66, 0.99, 1.91, 1.  , 1.97, 1.99, 3.  , 3.  , 0.  , 2.  ,
#        0.25, 1.7 , 3.  , 0.66, 3.  , 3.  , 0.09, 2.99, 0.04, 2.99, 0.84,
#        2.55, 0.01, 1.03, 1.96, 2.04, 0.29, 1.97, 1.61, 0.19, 1.66, 1.  ,
#        2.38, 0.9 , 0.03, 0.  , 2.89, 0.35, 2.08, 0.16, 0.95, 1.97, 3.  ,
#        2.99, 2.46, 1.01, 3.  , 2.9 , 3.  , 3.  , 1.74, 3.  , 0.03, 0.02,
#        2.86, 1.89, 1.02, 1.52, 0.09, 3.  , 2.2 , 2.81, 1.36, 0.  , 1.98,
#        1.18, 0.78, 2.98, 0.57, 1.58, 0.01, 3.  , 2.04, 0.95, 2.57, 1.07,
# ...
